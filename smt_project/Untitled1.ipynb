# %%
# %matplotlib inline
img_root='/home/junwon/mxnet_code/smt_project/data/101_ObjectCategories/airplanes/'

# %%
import os
import skimage.transform
import matplotlib.pyplot as plt
import matplotlib.image as mpimage

# %%
img_list=[]
for image in os.listdir(img_root):
    img_path = os.path.join(img_root,image)
    img = mpimage.imread(img_path)
    img = skimage.transform.resize(img,[128,128])
    print img.shape
    img_list.append(img)
# Out:
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# ...

# %%
plt.imshow(img_list[6])
